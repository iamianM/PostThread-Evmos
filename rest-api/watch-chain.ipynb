# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import time

from database_queries import update_db
import sqlite3
from web3_helpers import *
# Out:
# C:\Users\Mcian\AppData\Local\Programs\Python\Python39\lib\site-packages\eth_tester\backends\__init__.py:30: UserWarning: Ethereum Tester: No backend was explicitly set, and no *full* backends were available.  Falling back to the `MockBackend` which does not support all EVM functionality.  Please refer to the `eth-tester` documentation for information on what backends are available and how to set them.  Your py-evm package may need to be updated.
#   warnings.warn(UserWarning(
# F:\web3_messing_around\PostThread-Tron\rest-api\web3_helpers.py:15: ResourceWarning: unclosed file <_io.TextIOWrapper name='.MNEMONIC.json' mode='r' encoding='cp1252'>
#   MNEMONIC = json.load(open('.MNEMONIC.json'))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# F:\web3_messing_around\PostThread-Tron\rest-api\web3_helpers.py:18: ResourceWarning: unclosed file <_io.TextIOWrapper name='../backend/build/contracts/PostThread.json' mode='r' encoding='cp1252'>
#   build = json.load(open("../backend/build/contracts/PostThread.json"))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# F:\web3_messing_around\PostThread-Tron\rest-api\web3_helpers.py:19: ResourceWarning: unclosed file <_io.TextIOWrapper name='../backend/previous.json' mode='r' encoding='cp1252'>
#   prev = json.load(open("../backend/previous.json"))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\Mcian\AppData\Local\Programs\Python\Python39\lib\site-packages\ipfshttpclient\client\__init__.py:75: VersionMismatch: Unsupported daemon version '0.12.2' (not in range: 0.5.0 ≤ … < 0.9.0)
#   warnings.warn(exceptions.VersionMismatch(version, minimum, maximum))
# F:\web3_messing_around\PostThread-Tron\rest-api\web3_helpers.py:28: ResourceWarning: unclosed file <_io.TextIOWrapper name='schemas.json' mode='r' encoding='cp1252'>
#   schemas = json.load(open("schemas.json"))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# F:\web3_messing_around\PostThread-Tron\rest-api\database_queries.py:9: ResourceWarning: unclosed file <_io.TextIOWrapper name='schemas.json' mode='r' encoding='cp1252'>
#   schemas = json.load(open("schemas.json", "r"))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
con = sqlite3.connect('postthreadV1_write.db')
cur = con.cursor()

# %%
minted_time = 0
last_block = 0
while True:    
    current_block = w3.eth.get_block_number()
    if current_block != last_block:
        last_block = update_db(
            query_start=True, 
            backfill=False, schemaToUpdate=None
        )
        print("Block: ", current_block)
    
    time.sleep(1)
# Out:
# post 2
# comment 11
# vote 20
# user 2
# Block:  1834
# comment 2
# vote 1
# Block:  1844
# comment 1
# vote 1
# Block:  1847
# comment 1
# vote 2
# Block:  1850
# comment 1
# vote 2
# Block:  1853
# comment 1
# vote 2
# Block:  1856
# comment 1
# vote 2
# Block:  1858
# comment 1
# vote 2
# Block:  1861
# comment 1
# vote 2
# user 1
# Block:  1864
# post 1
# vote 2
# Block:  1866
# Block:  1869
# comment 1
# vote 2
# Block:  1872
# comment 1
# vote 2
# Block:  1875
# comment 1
# vote 2
# Block:  1878
# comment 1
# vote 2
# Block:  1881
# comment 1
# vote 2
# Block:  1884
# comment 1
# vote 2
# Block:  1887
# comment 1
# vote 2
# Block:  1890
# comment 1
# vote 2
# Block:  1892
# comment 1
# Block:  2731
# Block:  2734
# Block:  2737
# Block:  2740
# Block:  2744
# Block:  2748
# Block:  2751
# Block:  2752
# user 1
# Block:  2753
# post 1
# vote 2
# Block:  2756
# comment 1
# vote 2
# Block:  2759
# comment 1
# vote 2
# follow 5
# Block:  2763
# user 1
# Block:  2768
# post 1
# vote 2
# Block:  2771
# comment 1
# vote 2
# Block:  2774
# comment 1
# vote 2
# follow 5
# Block:  2778
# user 1
# Block:  2783
# post 1
# vote 2
# Block:  2786
# comment 1
# vote 2
# Block:  2789
# comment 1
# -----------------------------------------------------
# timeout             Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\AppData\Local\Programs\Python\Python39\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1376 try:
# -> 1377     response.begin()
#    1378 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\http\client.py:320, in HTTPResponse.begin(self)
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\socket.py:704, in SocketIO.readinto(self, b)
#     703 try:
# --> 704     return self._sock.recv_into(b)
#     705 except timeout:
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError    Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\packages\six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:451, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452     raise
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:340, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     339 if isinstance(err, SocketTimeout):
# --> 340     raise ReadTimeoutError(
#     341         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342     )
#     344 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     345 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPConnectionPool(host='127.0.0.1', port=8545): Read timed out. (read timeout=10)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout         Traceback (most recent call last)
# Input In [5], in <cell line: 4>()
#       4 current_block = w3.eth.get_block_number()
#       5 if current_block != last_block:
# ----> 6     last_block = update_db(
#       7         query_start=True,
#       8         backfill=False, schemaToUpdate=None
#       9     )
#      10     print("Block: ", current_block)
#      12 time.sleep(1)
#
# File F:\web3_messing_around\PostThread-Tron\rest-api\database_queries.py:53, in update_db(start_block, backfill, schemaToUpdate, query_start)
#      50     create_table = f"CREATE TABLE {schemaName} ({schemaValue}, {extraValues}, UNIQUE({names}))"
#      51     cur.execute(create_table)
# ---> 53 contents = postthread_contract.functions.getMessages(schemaId).call()
#      55 table_values = []
#      56 count = 0
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\contract.py:957, in ContractFunction.call(self, transaction, block_identifier, state_override)
#     951         raise ValueError(
#     952             "Please ensure that this contract instance has an address."
#     953         )
#     955 block_id = parse_block_identifier(self.web3, block_identifier)
# --> 957 return call_contract_function(
#     958     self.web3,
#     959     self.address,
#     960     self._return_data_normalizers,
#     961     self.function_identifier,
#     962     call_transaction,
#     963     block_id,
#     964     self.contract_abi,
#     965     self.abi,
#     966     state_override,
#     967     *self.args,
#     968     **self.kwargs
#     969 )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\contract.py:1501, in call_contract_function(web3, address, normalizers, function_identifier, transaction, block_id, contract_abi, fn_abi, state_override, *args, **kwargs)
#    1486 """
#    1487 Helper function for interacting with a contract function using the
#    1488 `eth_call` API.
#    1489 """
#    1490 call_transaction = prepare_transaction(
#    1491     address,
#    1492     web3,
#    (...)
#    1498     fn_kwargs=kwargs,
#    1499 )
# -> 1501 return_data = web3.eth.call(
#    1502     call_transaction,
#    1503     block_identifier=block_id,
#    1504     state_override=state_override,
#    1505 )
#    1507 if fn_abi is None:
#    1508     fn_abi = find_matching_fn_abi(contract_abi, web3.codec, function_identifier, args, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\module.py:57, in retrieve_blocking_method_call_fn.<locals>.caller(*args, **kwargs)
#      55     return LogFilter(eth_module=module, filter_id=err.filter_id)
#      56 result_formatters, error_formatters, null_result_formatters = response_formatters
# ---> 57 result = w3.manager.request_blocking(method_str,
#      58                                      params,
#      59                                      error_formatters,
#      60                                      null_result_formatters)
#      61 return apply_result_formatters(result_formatters, result)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\manager.py:197, in RequestManager.request_blocking(self, method, params, error_formatters, null_result_formatters)
#     187 def request_blocking(
#     188     self,
#     189     method: Union[RPCEndpoint, Callable[..., RPCEndpoint]],
#    (...)
#     192     null_result_formatters: Optional[Callable[..., Any]] = None,
#     193 ) -> Any:
#     194     """
#     195     Make a synchronous request using the provider
#     196     """
# --> 197     response = self._make_request(method, params)
#     198     return self.formatted_response(response,
#     199                                    params,
#     200                                    error_formatters,
#     201                                    null_result_formatters)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\manager.py:150, in RequestManager._make_request(self, method, params)
#     146 request_func = self.provider.request_func(
#     147     self.web3,
#     148     self.middleware_onion)
#     149 self.logger.debug("Making request. Method: %s", method)
# --> 150 return request_func(method, params)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\middleware\formatting.py:94, in construct_web3_formatting_middleware.<locals>.formatter_middleware.<locals>.middleware(method, params)
#      92     formatter = request_formatters[method]
#      93     params = formatter(params)
# ---> 94 response = make_request(method, params)
#      96 return _apply_response_formatters(method=method, response=response, **formatters)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\middleware\gas_price_strategy.py:90, in gas_price_strategy_middleware.<locals>.middleware(method, params)
#      86     transaction = validate_transaction_params(
#      87         transaction, latest_block, generated_gas_price
#      88     )
#      89     return make_request(method, (transaction,))
# ---> 90 return make_request(method, params)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\middleware\formatting.py:94, in construct_web3_formatting_middleware.<locals>.formatter_middleware.<locals>.middleware(method, params)
#      92     formatter = request_formatters[method]
#      93     params = formatter(params)
# ---> 94 response = make_request(method, params)
#      96 return _apply_response_formatters(method=method, response=response, **formatters)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\middleware\attrdict.py:33, in attrdict_middleware.<locals>.middleware(method, params)
#      32 def middleware(method: RPCEndpoint, params: Any) -> RPCResponse:
# ---> 33     response = make_request(method, params)
#      35     if 'result' in response:
#      36         result = response['result']
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\middleware\formatting.py:94, in construct_web3_formatting_middleware.<locals>.formatter_middleware.<locals>.middleware(method, params)
#      92     formatter = request_formatters[method]
#      93     params = formatter(params)
# ---> 94 response = make_request(method, params)
#      96 return _apply_response_formatters(method=method, response=response, **formatters)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\middleware\formatting.py:94, in construct_web3_formatting_middleware.<locals>.formatter_middleware.<locals>.middleware(method, params)
#      92     formatter = request_formatters[method]
#      93     params = formatter(params)
# ---> 94 response = make_request(method, params)
#      96 return _apply_response_formatters(method=method, response=response, **formatters)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\middleware\formatting.py:94, in construct_web3_formatting_middleware.<locals>.formatter_middleware.<locals>.middleware(method, params)
#      92     formatter = request_formatters[method]
#      93     params = formatter(params)
# ---> 94 response = make_request(method, params)
#      96 return _apply_response_formatters(method=method, response=response, **formatters)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\middleware\buffered_gas_estimate.py:40, in buffered_gas_estimate_middleware.<locals>.middleware(method, params)
#      34         transaction = assoc(
#      35             transaction,
#      36             'gas',
#      37             hex(get_buffered_gas_estimate(web3, transaction)),
#      38         )
#      39         return make_request(method, [transaction])
# ---> 40 return make_request(method, params)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\middleware\exception_retry_request.py:105, in exception_retry_middleware.<locals>.middleware(method, params)
#     103 for i in range(retries):
#     104     try:
# --> 105         return make_request(method, params)
#     106     # https://github.com/python/mypy/issues/5349
#     107     except errors:  # type: ignore
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\providers\rpc.py:88, in HTTPProvider.make_request(self, method, params)
#      85 self.logger.debug("Making request HTTP. URI: %s, Method: %s",
#      86                   self.endpoint_uri, method)
#      87 request_data = self.encode_rpc_request(method, params)
# ---> 88 raw_response = make_post_request(
#      89     self.endpoint_uri,
#      90     request_data,
#      91     **self.get_request_kwargs()
#      92 )
#      93 response = self.decode_rpc_response(raw_response)
#      94 self.logger.debug("Getting response HTTP. URI: %s, "
#      95                   "Method: %s, Response: %s",
#      96                   self.endpoint_uri, method, response)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\web3\_utils\request.py:48, in make_post_request(endpoint_uri, data, *args, **kwargs)
#      46 session = _get_session(endpoint_uri)
#      47 # https://github.com/python/mypy/issues/2582
# ---> 48 response = session.post(endpoint_uri, data=data, *args, **kwargs)  # type: ignore
#      49 response.raise_for_status()
#      51 return response.content
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py:577, in Session.post(self, url, data, json, **kwargs)
#     566 def post(self, url, data=None, json=None, **kwargs):
#     567     r"""Sends a POST request. Returns :class:`Response` object.
#     568
#     569     :param url: URL for the new :class:`Request` object.
#    (...)
#     574     :rtype: requests.Response
#     575     """
# --> 577     return self.request('POST', url, data=data, json=json, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\adapters.py:532, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     530     raise SSLError(e, request=request)
#     531 elif isinstance(e, ReadTimeoutError):
# --> 532     raise ReadTimeout(e, request=request)
#     533 elif isinstance(e, _InvalidHeader):
#     534     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPConnectionPool(host='127.0.0.1', port=8545): Read timed out. (read timeout=10)

# %%
update_db(backfill=True, schemaToUpdate=None)
# Out:
# Failed to get ipfs hash  {"category": "test", "title": "test", "body": "test", "url": "test", "is_nsfw": 0}
# post 10
# comment 25
# Failed to parse json {"post_hash": QmbG2dxLWHKvdgsTqDzLjhD96BXrLQUeJkrLuasmPZKgn9,"parent_hash": QmbG2dxLWHKvdgsTqDzLjhD96BXrLQUeJkrLuasmPZKgn9,"parent_type": post,"num_votes": 1}
# vote 68
# user 10
# follow 23
# link 1
# payout 1
# 1791
